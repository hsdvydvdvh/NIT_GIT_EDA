# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv("online (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 1           1          Yes        No Income   12.9770         Single    Male
# 2           2          Yes        No Income   12.9770         Single  Female
# 3           3          Yes        No Income   13.0019         Single  Female
# 4           4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          NaN  Positive    560009   NaN    77.5773
# 2           Student          NaN  Positive    560009   NaN    77.5773
# 3           Student          NaN  Positive    560003   NaN    77.5713
# 4    Self Employeed          NaN  Positive    560015   NaN    77.5284
#
#   Educational Qualifications Unnamed: 13   9           #@%
# 0              Post Graduate         Yes NaN  swiggyscount
# 1              Post Graduate         Yes NaN         *7435
# 2              Post Graduate         Yes NaN         *7435
# 3              Post Graduate         Yes NaN         *7435
# 4                     School         Yes NaN         *7435

# %%
df.shape
# Out:
# (388, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_status', 'Monthly Income', 'latitude',
#        'Marital Status', 'Gender', 'employment_status', 'Family size',
#        'Reviews', 'Pin code', 'Age', 'longitude', 'Educational Qualifications',
#        'Unnamed: 13', '9', '#@%'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                    19
# Reviews                         0
# Pin code                        0
# Age                            19
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             388
# #@%                           382
# dtype: int64

# %%
df.shape
# Out:
# (388, 12)

# %%
df.head()
# Out:
#   order_status   Monthly Income  latitude Marital Status  Gender  \
# 0          Yes   25001 to 50000   13.0262        Married    Male
# 1          Yes        No Income   12.9770         Single    Male
# 2          Yes        No Income   12.9770         Single  Female
# 3          Yes        No Income   13.0019         Single  Female
# 4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          NaN  Positive    560009   NaN    77.5773
# 2           Student          NaN  Positive    560009   NaN    77.5773
# 3           Student          NaN  Positive    560003   NaN    77.5713
# 4    Self Employeed          NaN  Positive    560015   NaN    77.5284
#
#   Educational Qualifications
# 0              Post Graduate
# 1              Post Graduate
# 2              Post Graduate
# 3              Post Graduate
# 4                     School

# %%
df.isnull().sum()
# Out:
# order_status                   0
# Monthly Income                 0
# latitude                       0
# Marital Status                 0
# Gender                         0
# employment_status              0
# Family size                   19
# Reviews                        0
# Pin code                       0
# Age                           19
# longitude                      0
# Educational Qualifications     0
# dtype: int64

# %% [markdown]
# # the process of filling the missing values in dataset is called inputation.

# %%
import pandas as pd

# %%
df = pd.read_csv("online (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 1           1          Yes        No Income   12.9770         Single    Male
# 2           2          Yes        No Income   12.9770         Single  Female
# 3           3          Yes        No Income   13.0019         Single  Female
# 4           4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          NaN  Positive    560009   NaN    77.5773
# 2           Student          NaN  Positive    560009   NaN    77.5773
# 3           Student          NaN  Positive    560003   NaN    77.5713
# 4    Self Employeed          NaN  Positive    560015   NaN    77.5284
#
#   Educational Qualifications Unnamed: 13   9           #@%
# 0              Post Graduate         Yes NaN  swiggyscount
# 1              Post Graduate         Yes NaN         *7435
# 2              Post Graduate         Yes NaN         *7435
# 3              Post Graduate         Yes NaN         *7435
# 4                     School         Yes NaN         *7435

# %%
# mean inputation 
family_mean=int(df["Family size"].mean())

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("online (1).csv")

# %%
sns.boxplot(df['Family size'])
# Out:
# <Axes: ylabel='Family size'>

# %%
family_mean
# Out:
# 3

# %%
#to fill missing value in column we use fillna function
df["Family size"].fillna(family_mean,inplace=True)
# Out:
# C:\Users\ejjig\AppData\Local\Temp\ipykernel_8484\1057255187.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Family size"].fillna(family_mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                     0
# Reviews                         0
# Pin code                        0
# Age                            19
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             388
# #@%                           382
# dtype: int64

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ejjig\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\ejjig\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ejjig\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ejjig\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ejjig\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ejjig\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\ejjig\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.8 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.8 MB 1.3 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/7.8 MB 1.3 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.8 MB 1.3 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.8 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/7.8 MB 1.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/7.8 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.4/7.8 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.6/7.8 MB 1.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.1/7.8 MB 1.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.4/7.8 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/7.8 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 3.9/7.8 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 4.5/7.8 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/7.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.0/7.8 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.5/7.8 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/7.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/7.8 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.3/7.8 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 6.6/7.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 1.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.2 MB 1.3 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 1.2 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.6 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.6 MB 1.3 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.4 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ejjig\appdata\local\programs\python\python312\lib\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# medain inputation
age_median = int(df["Age"].median())

# %%
age_median
# Out:
# 24

# %%
# to fill missing values in aa column 
df["Age"].fillna(age_median,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                     0
# Reviews                         0
# Pin code                        0
# Age                             0
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             388
# #@%                           382
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 1           1          Yes        No Income   12.9770         Single    Male
# 2           2          Yes        No Income   12.9770         Single  Female
# 3           3          Yes        No Income   13.0019         Single  Female
# 4           4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          3.0  Positive    560009  24.0    77.5773
# 2           Student          3.0  Positive    560009  24.0    77.5773
# 3           Student          3.0  Positive    560003  24.0    77.5713
# 4    Self Employeed          3.0  Positive    560015  24.0    77.5284
#
#   Educational Qualifications Unnamed: 13   9           #@%
# 0              Post Graduate         Yes NaN  swiggyscount
# 1              Post Graduate         Yes NaN         *7435
# 2              Post Graduate         Yes NaN         *7435
# 3              Post Graduate         Yes NaN         *7435
# 4                     School         Yes NaN         *7435

# %%
import pandas as pd

# %%
df.head()
# Out:
#   order_status   Monthly Income  latitude Marital Status  Gender  \
# 0          Yes   25001 to 50000   13.0262        Married    Male
# 1          Yes        No Income   12.9770         Single    Male
# 2          Yes        No Income   12.9770         Single  Female
# 3          Yes        No Income   13.0019         Single  Female
# 4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          3.0  Positive    560009  24.0    77.5773
# 2           Student          3.0  Positive    560009  24.0    77.5773
# 3           Student          3.0  Positive    560003  24.0    77.5713
# 4    Self Employeed          3.0  Positive    560015  24.0    77.5284
#
#   Educational Qualifications
# 0              Post Graduate
# 1              Post Graduate
# 2              Post Graduate
# 3              Post Graduate
# 4                     School

# %%
df.shape
# Out:
# (388, 12)

# %%
df.isnull().sum()
# Out:
# order_status                  0
# Monthly Income                0
# latitude                      0
# Marital Status                0
# Gender                        0
# employment_status             0
# Family size                   0
# Reviews                       0
# Pin code                      0
# Age                           0
# longitude                     0
# Educational Qualifications    0
# dtype: int64

# %%
# lower limit =q1-1.5*IQR
# upper limit = q3 + 1.5*IQR
df.describe()
# Out:
#          latitude  Family size       Pin code         Age   longitude
# count  388.000000   388.000000     388.000000  388.000000  388.000000
# mean    12.972058     3.283505  560040.113402   24.634021   77.600160
# std      0.044489     1.322450      31.399609    2.897932    0.051354
# min     12.865200     1.000000  560001.000000   18.000000   77.484200
# 25%     12.936900     2.000000  560010.750000   23.000000   77.565275
# 50%     12.977000     3.000000  560033.500000   24.000000   77.592100
# 75%     12.997025     4.000000  560068.000000   26.000000   77.630900
# max     13.102000     6.000000  560109.000000   33.000000   77.758200

# %%
q1= int(df.describe()["Age"]["25%"])

# %%
q3= int(df.describe()["Age"]["75%"])

# %%
IQR=q3 - q1
print(IQR)
# Out:
# 3

# %%
lower_limit =q1-1.5*IQR
upper_limit = q3 + 1.5*IQR

# %%
lower_limit
# Out:
# 18.5

# %%
upper_limit
# Out:
# 30.5

# %%
df[(df["Age"]>upper_limit) | (df["Age"]<lower_limit)].count()
# Out:
# Unnamed: 0                    24
# order_status                  24
# Monthly Income                24
# latitude                      24
# Marital Status                24
# Gender                        24
# employment_status             24
# Family size                   24
# Reviews                       24
# Pin code                      24
# Age                           24
# longitude                     24
# Educational Qualifications    24
# Unnamed: 13                   24
# 9                              0
# #@%                            0
# dtype: int64

# %%
# the outliers
df[(df["Age"]>upper_limit) | (df["Age"]<lower_limit)]
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude     Marital Status  \
# 16           16          Yes   25001 to 50000   12.9706            Married
# 26           26          Yes   10001 to 25000   12.9820            Married
# 31           31           No  More than 50000   13.0019            Married
# 33           33           No        No Income   13.0140            Married
# 71           71          Yes   25001 to 50000   12.9706            Married
# 74           74          Yes  More than 50000   12.9037            Married
# 98           98          Yes  More than 50000   12.9369            Married
# 105         105          Yes  More than 50000   13.0487            Married
# 139         139          Yes        No Income   12.9889            Married
# 147         147          Yes        No Income   12.9635             Single
# 151         151          Yes   10001 to 25000   12.9783            Married
# 153         153           No  More than 50000   12.9980            Married
# 157         157          Yes  More than 50000   12.9369            Married
# 175         175          Yes  More than 50000   12.9306            Married
# 228         228          Yes  More than 50000   12.9119            Married
# 232         232           No   Below Rs.10000   12.9866  Prefer not to say
# 260         260          Yes  More than 50000   12.9037            Married
# 263         263          Yes  More than 50000   12.9635            Married
# 308         308           No   Below Rs.10000   12.9866  Prefer not to say
# 332         332          Yes        No Income   12.9850            Married
# 337         337          Yes   25001 to 50000   12.9261            Married
# 351         351          Yes        No Income   13.0289            Married
# 355         355          Yes   25001 to 50000   12.9706            Married
# 369         369          Yes  More than 50000   12.9662            Married
#
#      Gender employment_status  Family size    Reviews  Pin code   Age  \
# 16     Male          Employee          3.0   Positive    560075  32.0
# 26     Male    Self Employeed          3.0  Negative     560008  32.0
# 31   Female          Employee          1.0   Positive    560003  32.0
# 33   Female        House wife          3.0   Positive    560012  32.0
# 71     Male          Employee          3.0   Positive    560075  32.0
# 74     Male          Employee          5.0   Positive    560061  32.0
# 98     Male          Employee          6.0   Positive    560095  32.0
# 105    Male    Self Employeed          6.0   Positive    560024  31.0
# 139  Female        House wife          5.0   Positive    560020  32.0
# 147    Male           Student          5.0   Positive    560002  18.0
# 151    Male          Employee          4.0   Positive    560038  32.0
# 153    Male          Employee          5.0  Negative     560005  33.0
# 157    Male          Employee          6.0   Positive    560095  32.0
# 175    Male          Employee          3.0   Positive    560085  31.0
# 228    Male          Employee          5.0   Positive    560102  31.0
# 232    Male          Employee          1.0  Negative     560091  31.0
# 260    Male          Employee          5.0   Positive    560061  32.0
# 263    Male          Employee          5.0  Negative     560002  32.0
# 308    Male          Employee          1.0  Negative     560091  31.0
# 332  Female        House wife          3.0   Positive    560010  32.0
# 337  Female          Employee          5.0   Positive    560034  32.0
# 351  Female        House wife          5.0   Positive    560022  31.0
# 355    Male          Employee          3.0   Positive    560075  32.0
# 369  Female          Employee          5.0   Positive    560025  31.0
#
#      longitude Educational Qualifications Unnamed: 13   9  #@%
# 16     77.6529                   Graduate         Yes NaN  NaN
# 26     77.6256                     School         Yes NaN  NaN
# 31     77.5713                   Graduate          No NaN  NaN
# 33     77.5658                 Uneducated          No NaN  NaN
# 71     77.6529                   Graduate         Yes NaN  NaN
# 74     77.5376                   Graduate         Yes NaN  NaN
# 98     77.6407              Post Graduate         Yes NaN  NaN
# 105    77.5923                     School         Yes NaN  NaN
# 139    77.5741                     School         Yes NaN  NaN
# 147    77.5821                   Graduate         Yes NaN  NaN
# 151    77.6408                   Graduate         Yes NaN  NaN
# 153    77.6227                       Ph.D          No NaN  NaN
# 157    77.6407              Post Graduate         Yes NaN  NaN
# 175    77.5434                       Ph.D         Yes NaN  NaN
# 228    77.6446                       Ph.D         Yes NaN  NaN
# 232    77.4904                   Graduate          No NaN  NaN
# 260    77.5376                   Graduate         Yes NaN  NaN
# 263    77.5821                       Ph.D         Yes NaN  NaN
# 308    77.4904                   Graduate          No NaN  NaN
# 332    77.5533                   Graduate         Yes NaN  NaN
# 337    77.6221                   Graduate         Yes NaN  NaN
# 351    77.5400                     School         Yes NaN  NaN
# 355    77.6529                   Graduate         Yes NaN  NaN
# 369    77.6068                       Ph.D         Yes NaN  NaN

# %%
# removing the outliers(trimming)
df[(df["Age"]<upper_limit) & (df["Age"]>lower_limit)].count()
# Out:
# Unnamed: 0                    345
# order_status                  345
# Monthly Income                345
# latitude                      345
# Marital Status                345
# Gender                        345
# employment_status             345
# Family size                   345
# Reviews                       345
# Pin code                      345
# Age                           345
# longitude                     345
# Educational Qualifications    345
# Unnamed: 13                   345
# 9                               0
# #@%                             2
# dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv("online (1).csv")

# %%
new_df=df[(df["Age"]<upper_limit) & (df["Age"]>lower_limit)]

# %%
new_df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 5           5          Yes        No Income   12.9369         Single  Female
# 6           6          Yes  More than 50000   12.9442        Married    Male
# 7           7           No   25001 to 50000   13.0103         Single  Female
# 8           8          Yes   10001 to 25000   12.9820        Married    Male
#
#   employment_status  Family size    Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0   Positive    560045  28.0    77.6200
# 5           Student          2.0   Positive    560095  22.0    77.6407
# 6          Employee          6.0   Positive    560030  25.0    77.6076
# 7    Self Employeed          3.0  Negative     560080  24.0    77.5796
# 8    Self Employeed          3.0  Negative     560008  22.0    77.6256
#
#   Educational Qualifications Unnamed: 13   9           #@%
# 0              Post Graduate         Yes NaN  swiggyscount
# 5                   Graduate         Yes NaN         *7435
# 6              Post Graduate         Yes NaN           NaN
# 7              Post Graduate          No NaN           NaN
# 8                     School         Yes NaN           NaN

# %%
import seaborn as sns

# %%
sns.boxplot(new_df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
# capping techniques
df["Age"].clip(lower_limit,upper_limit,inplace=True)
# Out:
# C:\Users\ejjig\AppData\Local\Temp\ipykernel_14428\2735311850.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].clip(lower_limit,upper_limit,inplace=True)
